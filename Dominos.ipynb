# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import nbimporter
from classes import MyStock

pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# <center>
#     <img src="images/dominos_logo.png" width="30%" />
# </center>

# %% [markdown]
# <table>
#     <tr>
#         <th>Founders</th>
#         <th>Headquarters</th>
#         <th>Locations</th>
#         <th>Founded</th>
#     </tr>
#     <tr align="center">
#         <td>
#             James Monaghan<br/>
#             Tom Monaghan<br/>
#             Dominick DeVarti
#         </td>
#         <td>Ann Arbor, Michigan</td>
#         <td>17,000</td>
#         <td>December 9, 1960</td>
#     </tr>
# </table>
#
# <table>
#     <tr>
#         <th>Exchange</th>
#         <th>1st Trade Date</th>
#         <th>Ticker</th>
#     </tr>
#     <tr align="center">
#         <td>NYSE</td>
#         <td>July 13, 2004</td>
#         <td>DPZ</td>
#     </tr>
# </table>

# %% [markdown]
# <center>
#     <h3>Key Points</h3>
# </center>
# <ul>
#     <li>
#        In 1960, Tom &amp; James Monaghan took over a DomiNick's, an existing location of a small pizza restaurant chain that had been owned by Dominick DeVarti, in Ypsilanti, Michigan near Eastern Michigan University. The deal was secured by a &#36;500 down payment, then borrowed &#36;900 to pay for the store.<br/><br/>
#         <center>
#             <img src="images/DomiNicks.jpeg" width="50%" />
#         </center>
#     </li>
#     <li>
#         James kept his full-time job as a postman to keep up costs of the business. Within eight months, James traded his half of the business to Tom for the Volkswagen Beetle they used for pizza deliveries.<br/><br/>
#     </li>
#     <li>
#         By 1965, Tom Monaghan had purchased two additional pizzerias in the same county. The original owner forbade him from using the name "DomiNick's", so Tom renamed the restaurants to <i>Domino's Pizza Inc.</i> after an employee, Jim Kennedy suggested the name. The 3 dots in the logo represent the 3 original restaurants.
#         <br/><br/>
#     </li>
#     <li>
#         Domino's Pizza opened its first franchise location in 1967 and by 1978, the company had expanded to 200 stores <br/><br/>
#     </li>
#     <li>
#        In 1975, a lawsuit by Amstar Corporation, the maker of Domino Sugar, alleging trademark infringement and unfair competition. On May 2, 1980, the Fifth Circuit Court of Appeals in New Orleans found in favor of Domino's Pizza.<br/><br/>
#        <center>
#             <img src="images/domino-sugar-logo-png-transparent.png" width="20%" />
#         </center>
#         <br><br>
#     </li>
#     <li>
#         In 1998, after 38 years of ownership, Domino's founder Tom Monaghan retired, sold 93 percent of the company to Bain Capital, Inc. for about &#36;1 billion, and ceased being involved in day-to-day operations of the company. A year later, the company named Dave Brandon as its CEO.<br/><br/>
#     </li>
# </ul>

# %%
# Complete
pizza_cos = {
    "papa_johns": 1,
    "dominos": 2
}

my_stock = MyStock.MyStock()

# %% [markdown]
# <center><h2>Create <em>'company_df'</em> </h2>

# %%
# Complete
co_cols = ['Company_ID', 'Full_Name', 'Ticker', 'ex1', 'ex2', 'ex3', 'ex4']

company_df = my_stock.create_DF(co_cols, co_cols[0:3], 'data/stock_company.csv')

company_df
# Out:
#    Company_ID       Full_Name Ticker
# 0           1     Papa John's   PZZA
# 1           2  Domino's Pizza    DPZ

# %% [markdown]
# <center>
#     <img src="images/the_noid.jpeg" width="50%" />
# </center>

# %% [markdown]
# - 1986: Group 243 Inc. creates "The Noid" with associated catchphrase "Avoid the Noid". The Noid was discontinued after Kenneth Lamar Noid, believing the mascot to be an imitation of him, held two Domino's employees hostage in Chamblee, Georgia. The employees escaped while Noid ate a pizza he had ordered.

# %% [markdown]
# <center>
#     <h2>Create <em>'quotes_df'</em></h2>

# %%
# Complete
stock_cols = ['ID', 'str_date', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj_close', 'Volume', 'Created', 'Updated', 'Company_ID']

quotes_df = my_stock.create_DF(stock_cols, 'custom', 'data/stock_quotes.csv')

quotes_df
# Out:
#              Date   Open   High    Low  Close  Volume  Company_ID
# 0      2021-11-23 534.20 536.63 526.30 531.91  277800           2
# 1      2021-11-22 532.99 538.81 528.76 533.36  298800           2
# 2      2021-11-19 546.17 549.51 534.42 535.59  615400           2
# 3      2021-11-02 488.06 490.03 478.36 486.87  462500           2
# 4      2021-11-01 489.68 489.68 479.39 487.38  457100           2
# ...           ...    ...    ...    ...    ...     ...         ...
# 11776  2021-12-16 132.68 132.78 128.00 129.03  247000           1
# 11777  2021-12-15 126.92 131.66 126.36 131.58  305300           1
# 11778  2021-12-14 127.88 129.49 126.90 128.14  417600           1
# 11779  2021-12-13 128.61 128.96 126.61 128.23  275400           1
# 11780  2021-12-10 130.75 130.97 127.78 128.34  189900           1
#
# [11781 rows x 7 columns]

# %% [markdown]
# <center>
#     <h2>Merge Company &amp; Quote DF's</h2>

# %%
pj_x_dom_df = pd.merge(company_df, quotes_df, on='Company_ID')

pj_x_dom_df.drop('Company_ID', axis=1, inplace=True)

pj_x_dom_df
# Out:
#             Full_Name Ticker        Date   Open   High    Low  Close  Volume
# 0         Papa John's   PZZA  2021-11-29 128.90 130.19 126.00 126.21  418800
# 1         Papa John's   PZZA  2021-11-26 132.42 135.80 128.37 128.84  393800
# 2         Papa John's   PZZA  2021-11-24 128.53 133.95 128.53 133.84  328200
# 3         Papa John's   PZZA  2021-11-23 130.53 132.23 128.22 130.52  372400
# 4         Papa John's   PZZA  2021-11-22 132.54 134.37 129.90 130.50  342800
# ...               ...    ...         ...    ...    ...    ...    ...     ...
# 11776  Domino's Pizza    DPZ  2021-12-16 527.17 534.31 520.45 532.20  361200
# 11777  Domino's Pizza    DPZ  2021-12-15 510.92 525.40 507.44 523.92  515000
# 11778  Domino's Pizza    DPZ  2021-12-14 531.13 536.12 522.15 523.15  429600
# 11779  Domino's Pizza    DPZ  2021-12-13 533.40 540.96 530.49 537.36  448600
# 11780  Domino's Pizza    DPZ  2021-12-10 531.91 535.81 529.27 534.42  315700
#
# [11781 rows x 8 columns]

# %% [markdown]
# <center>
#     <h2>Create Domino's DF</h2>

# %%
dom_ticker = pj_x_dom_df['Ticker'].loc[pj_x_dom_df['Full_Name'] == "Domino's Pizza"].unique()

dom_df = pj_x_dom_df.loc[pj_x_dom_df['Ticker'] == dom_ticker[0]]

dom_df
# Out:
#             Full_Name Ticker        Date   Open   High    Low  Close  Volume
# 7288   Domino's Pizza    DPZ  2021-11-23 534.20 536.63 526.30 531.91  277800
# 7289   Domino's Pizza    DPZ  2021-11-22 532.99 538.81 528.76 533.36  298800
# 7290   Domino's Pizza    DPZ  2021-11-19 546.17 549.51 534.42 535.59  615400
# 7291   Domino's Pizza    DPZ  2021-11-02 488.06 490.03 478.36 486.87  462500
# 7292   Domino's Pizza    DPZ  2021-11-01 489.68 489.68 479.39 487.38  457100
# ...               ...    ...         ...    ...    ...    ...    ...     ...
# 11776  Domino's Pizza    DPZ  2021-12-16 527.17 534.31 520.45 532.20  361200
# 11777  Domino's Pizza    DPZ  2021-12-15 510.92 525.40 507.44 523.92  515000
# 11778  Domino's Pizza    DPZ  2021-12-14 531.13 536.12 522.15 523.15  429600
# 11779  Domino's Pizza    DPZ  2021-12-13 533.40 540.96 530.49 537.36  448600
# 11780  Domino's Pizza    DPZ  2021-12-10 531.91 535.81 529.27 534.42  315700
#
# [4493 rows x 8 columns]

# %% [markdown]
# <center>
#     <h2> Describe</h2>
# </center>

# %%
dom_df.describe()
# Out:
#          Open    High     Low   Close      Volume
# count 4493.00 4493.00 4493.00 4493.00     4493.00
# mean   125.71  127.23  124.26  125.79   664566.73
# std    141.08  142.87  139.40  141.16   599878.72
# min      2.92    3.06    2.61    2.83    43000.00
# 25%     18.40   18.56   18.21   18.37   370200.00
# 50%     59.25   60.10   58.76   59.45   528900.00
# 75%    208.33  210.77  206.00  208.46   778400.00
# max    563.88  567.57  557.40  564.33 14964100.00

# %% [markdown]
# <center>
#     <h2><span>Find Duplicates &amp; Remove</span></h2>
#     <img src="https://img.icons8.com/external-flat-juicy-fish/60/000000/external-duplicate-cyber-crime-flat-flat-juicy-fish.png"/>
#     <hr>

# %%
print(dom_df.loc[dom_df.duplicated() == True])

# Drop duplicate(s)
dom_df = dom_df.drop_duplicates()

dom_df.loc[dom_df.duplicated() == True]
# Out:
#             Full_Name Ticker        Date   Open   High    Low  Close  Volume
# 11780  Domino's Pizza    DPZ  2021-12-10 531.91 535.81 529.27 534.42  315700
# Empty DataFrame
# Columns: [Full_Name, Ticker, Date, Open, High, Low, Close, Volume]
# Index: []

# %% [markdown]
# <center>
#     <h3>First Trade Date</h3>
# </center>

# %%
dom_df.loc[dom_df['Date'] == dom_df['Date'].min()]
# Out:
#            Full_Name Ticker        Date  Open  High   Low  Close    Volume
# 7293  Domino's Pizza    DPZ  2004-07-13 14.00 14.10 13.49  13.50  14964100

# %% [markdown]
# <center>
#     <h2>Create <em>year</em>, <em>month</em> &amp; <em>day of week</em></h2>

# %%
# Create Year
dom_df['Year'] = pd.DatetimeIndex(dom_df['Date'] ).year
sorted(dom_df['Year'].unique())

# Create Month
dom_df['Month'] = pd.DatetimeIndex( dom_df['Date'] ).month

## Day of the week
dom_df['Date'] = pd.to_datetime(dom_df['Date'])
dom_df['Date'] = pd.to_datetime(dom_df['Date'])
dom_df['DayOfWeek'] = dom_df['Date'].dt.day_name()

dom_df
# Out:
# /tmp/ipykernel_506583/3095324211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dom_df['Year'] = pd.DatetimeIndex(dom_df['Date'] ).year
# /tmp/ipykernel_506583/3095324211.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dom_df['Month'] = pd.DatetimeIndex( dom_df['Date'] ).month
# /tmp/ipykernel_506583/3095324211.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# <center>
#     <h2>Create DF's by <em>Year</em>, <em>Ticker</em>

# %%
# Complete
# Pass

dom_2015_df = my_stock.df_by_year(dom_df, 2015, 'DPZ')
dom_2016_df = my_stock.df_by_year(dom_df, 2016, 'DPZ')
dom_2017_df = my_stock.df_by_year(dom_df, 2017, 'DPZ')
dom_2018_df = my_stock.df_by_year(dom_df, 2018, 'DPZ')
dom_2019_df = my_stock.df_by_year(dom_df, 2019, 'DPZ')

# Pandemic
dom_2020_df = my_stock.df_by_year(dom_df, 2020, 'DPZ')
dom_2021_df = my_stock.df_by_year(dom_df, 2021, 'DPZ')
dom_2021_df
# Out:
#             Full_Name Ticker       Date   Open   High    Low  Close  Volume  \
# 7288   Domino's Pizza    DPZ 2021-11-23 534.20 536.63 526.30 531.91  277800
# 7289   Domino's Pizza    DPZ 2021-11-22 532.99 538.81 528.76 533.36  298800
# 7290   Domino's Pizza    DPZ 2021-11-19 546.17 549.51 534.42 535.59  615400
# 7291   Domino's Pizza    DPZ 2021-11-02 488.06 490.03 478.36 486.87  462500
# 7292   Domino's Pizza    DPZ 2021-11-01 489.68 489.68 479.39 487.38  457100
# ...               ...    ...        ...    ...    ...    ...    ...     ...
# 11775  Domino's Pizza    DPZ 2021-12-17 531.22 534.41 527.00 528.38  645100
# 11776  Domino's Pizza    DPZ 2021-12-16 527.17 534.31 520.45 532.20  361200
# 11777  Domino's Pizza    DPZ 2021-12-15 510.92 525.40 507.44 523.92  515000
# 11778  Domino's Pizza    DPZ 2021-12-14 531.13 536.12 522.15 523.15  429600
# 11779  Domino's Pizza    DPZ 2021-12-13 533.40 540.96 530.49 537.36  448600
#
#        Year  Month  DayOfWeek
# ...

# %% [markdown]
# <center>
#     <h2>HeatMap</h2>

# %%
# Complete

fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(dom_2019_df.corr(method='pearson').drop(['Year', 'Month']), linewidths=.5, annot=True, ax=ax);

# %% [markdown]
# <center>
#     <h3>Plot a continous line by <em>Date &amp; Close Price</em> (2015 - 2019)</h3>
#     Sort 2019
#     <img src="images/dom_unsort_plot.png" width="75%" />
# </center>

# %%
sns.set()
plt.figure(figsize=(22,6))

dom_2019_df = dom_2019_df.sort_values(by='Date')

# Tuple of Df's by year to create our line
dfs_to_plot = (dom_2015_df, dom_2016_df, dom_2017_df, dom_2018_df, dom_2019_df)

my_stock.dfs_to_plt(dfs_to_plot, 'Date', 'Close')

plt.legend();
plt.show()

# %% [markdown]
# <center>
#     <img src="images/dominos_car.jpeg" width="50%" />
# </center>

# %% [markdown]
# In 2015, Domino's unveiled a "pizza car" that can carry 80 pizzas, sides, 2-liter bottles of soda, and dipping sauces. It also has a 140-degrees Fahrenheit oven on board and fuel efficient. The *Domino's DXP* is a Chevrolet Spark customized by Roush Performance. Once each car reaches 100,000 miles, it will be retired and returned to Roush, where it will be returned to stock form.

# %%
# Domino's (2020, 2021)

plt.figure(figsize=(22,6))

dom_2021_df = dom_2021_df.sort_values(by='Date')

dfs_to_plot = (dom_2020_df, dom_2021_df)

my_stock.dfs_to_plt(dfs_to_plot, 'Date', 'Close')

plt.legend();

plt.show()

# %% [markdown]
# <center>
#     <img src="images/large-dominos-photo-asphalt.webp" width="50%" />
# </center>

# %% [markdown]
# 2018: Domino's announced that it had started a project to pave over cracks and potholes on roads in the United States called *"Paving for Pizza"* to prevent their pizzas from being ruined, giving cities and towns grants for road repairs. The company had reached an agreement with four cities and towns, including Burbank, California; Bartonville, Texas; Athens, Georgia; and Milford, Delaware to pave their roads. The paved sections feature the Domino's logo along with the slogan **"OH YES, WE DID"**.

# %% [markdown]
# <center>
#     <h1>Histogram 2015 - 2019</h1>
# </center>

# %%
dfs_to_plot = (dom_2015_df, dom_2016_df, dom_2017_df, dom_2018_df, dom_2019_df)
col = 'Close'

my_stock.hist_to_plot(dfs_to_plot, col, 20, (22, 12));
# Out:
# /home/vahuja/.local/lib/python3.8/site-packages/matplotlib/text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# <center>
#     <img src="images/dominos_nuro_r2.webp" width="50%" />
# </center>

# %% [markdown]
# June 2019, Domino's announced a partnership with robotics company Nuro and launches the self-driving vehicle, R2.

# %% [markdown]
# <center>
#     <h1>Histogram 2020 - 2021</h1>
# </center>

# %%
dfs_to_plot = (dom_2020_df, dom_2021_df)
col = 'Close'

my_stock.hist_to_plot(dfs_to_plot, col, 25, (22, 12));

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

sns.scatterplot(ax=axes[0,0], data=dom_2018_df, x="Date", y="Close", hue="Volume");

sns.scatterplot(ax=axes[0,1], data=dom_2019_df, x="Date", y="Close", hue="Volume");

sns.scatterplot(ax=axes[1,0], data=dom_2020_df, x="Date", y="Close", hue="Volume");

sns.scatterplot(ax=axes[1,1], data=dom_2021_df, x="Date", y="Close", hue="Volume");

# %% [markdown]
# ### Aggregates

# %%
dom_2015OpenMix       = dom_2015_df['Open'].median().mean().min().max()
dom_2015OpenMedian    = dom_2015_df['Open'].median()
dom_2015MonthOpenMean = dom_2015_df['Open'].mean()
dom_2015MonthMin      = dom_2015_df['Open'].min()
dom_2015MonthMax      = dom_2015_df['Open'].max()
dom_2015MonthStd      = dom_2015_df['Open'].std()

print(f"Mix: {dom_2015OpenMix:.2f}, Median: {dom_2015OpenMedian:.2f}, Mean: {dom_2015MonthOpenMean:.2f}, Min: {dom_2015MonthMin:.2f}, Max: {dom_2015MonthMax:.2f}, Std: {dom_2015MonthStd:.2f}")

var_open = 'Open'
dom_2015_df.agg({var_open : ['sum', 'min', 'max', 'std', 'mean']})
# Out:
# Mix: 107.73, Median: 107.73, Mean: 106.66, Min: 94.30, Max: 119.22, Std: 5.23
#          Open
# sum  26879.38
# min     94.30
# max    119.22
# std      5.23
# mean   106.66

# %% [markdown]
# <center>
#     <h3>DF By Month &amp; Describe (2019)</h3>
# </center>

# %%
# Months
sorted(dom_2019_df['Month'].unique())

dom_2019Jan_df = dom_2019_df.loc[ dom_2019_df['Month'] == 1 ]
dom_2019Jan_df.describe()

dom_2019Feb_df = dom_2019_df.loc[ dom_2019_df['Month'] == 2 ]
dom_2019Feb_df.describe()

dom_2019Mar_df = dom_2019_df.loc[ dom_2019_df['Month'] == 3 ]
dom_2019Mar_df.describe()
# Out:
#         Open   High    Low  Close     Volume    Year  Month
# count  21.00  21.00  21.00  21.00      21.00   21.00  21.00
# mean  247.30 249.85 244.03 247.03  820376.19 2019.00   3.00
# std     3.74   3.63   3.43   4.36  235484.30    0.00   0.00
# min   239.52 244.30 239.17 239.25  454700.00 2019.00   3.00
# 25%   244.80 247.99 241.93 244.27  682300.00 2019.00   3.00
# 50%   247.44 249.04 244.81 247.25  776300.00 2019.00   3.00
# 75%   249.67 251.15 245.26 248.76  922500.00 2019.00   3.00
# max   255.00 260.51 254.17 258.10 1329500.00 2019.00   3.00

# %% [markdown]
# <center>
#     <h3>Mean close by month</h3>
# </center>

# %%
print(
    dom_2015Jan_df['Close'].mean(), 
    dom_2015Feb_df['Close'].mean(), 
    dom_2015Mar_df['Close'].mean()
)

print(
    dom_2019Jan_df['Close'].mean(), 
    dom_2019Feb_df['Close'].mean(), 
    dom_2019Mar_df['Close'].mean()
)
# Out:
# 98.53900030000001 101.13684163157895 101.90681845454546
# 258.8271447619048 275.7384210526316 247.02571538095236

# %% [markdown]
# <center>
#     <h3>Plot mean by month for 2015 - 2019</h3>
# </center>

# %%
dfs_to_plot = (dom_2015_df, dom_2016_df, dom_2017_df, dom_2018_df, dom_2019_df)

plt.figure(figsize=(18,6))

dom_2015_mean = dom_2015_df.groupby('Month').mean()
dom_2016_mean = dom_2016_df.groupby('Month').mean()
dom_2017_mean = dom_2017_df.groupby('Month').mean()
dom_2018_mean = dom_2018_df.groupby('Month').mean()
dom_2019_mean = dom_2019_df.groupby('Month').mean()

plot_df = pd.DataFrame({
    '2015' : dom_2015_mean['Close'], 
    '2016' : dom_2016_mean['Close'], 
    '2017' : dom_2017_mean['Close'],
    '2018' : dom_2018_mean['Close'],
    '2019' : dom_2019_mean['Close'],
})

plt.plot(plot_df['2015'], label='2015')
plt.plot(plot_df['2016'], label='2016')
plt.plot(plot_df['2017'], label='2017')
plt.plot(plot_df['2018'], label='2018')
plt.plot(plot_df['2019'], label='2019')

plt.legend(title="Domino's Pizza", loc='upper right')

plt;

# %%
# TODO: Don't hard code names

plt.figure(figsize=(18,6))
dom_2020_mean = dom_2020_df.groupby('Month').mean()
dom_2021_mean = dom_2021_df.groupby('Month').mean()

plot_df = pd.DataFrame({
    '2020' : dom_2020_mean['Close'], 
    '2021' : dom_2021_mean['Close']
})

plt.plot(plot_df['2020'], label="2020")
plt.plot(plot_df['2021'], label="2021")
plt.legend(title = "Domino's Pizza", loc='upper right')
plt;

# %% [markdown]
# ### Bar

# %%
plt.figure(figsize=(18,8))

x = ["2015", "2016", "2017", "2018", "2019", "2020", "2021"]
y = [
    dom_2015_df['Close'].mean(), 
    dom_2016_df['Close'].mean(), 
    dom_2017_df['Close'].mean(), 
    dom_2018_df['Close'].mean(), 
    dom_2019_df['Close'].mean(),
    dom_2020_df['Close'].mean(),
    dom_2021_df['Close'].mean(),
]


plt.bar(x,y, color = ["#4CAF50", 'purple', '#000', 'red',  'pink', 'yellow', 'blue'])

plt.show()

# %% [markdown]
# <center>
#     <h3>Mean Open/Close/High/Low by Month (2020)</h3>
# </center>

# %%
# Cols to stack
cols_to_plot = {
    'Open': [],
    'Low':  [],
    'High': [],
    'Close':[]
}

# Get unique months
unique_months = dom_2020_df['Month'].unique()

# Month by name
month_name = pd.DatetimeIndex( dom_2020_df['Date'] ).month_name().unique()

# prepare our data for the the DataFrame
for un_m in unique_months:
    for col_key, col_vals_list in cols_to_plot.items():
        col_vals_list.append(dom_2020_df[col_key].loc[dom_2020_df['Month'] == un_m].mean())

# Create DF from dict
df_2020_open_close = pd.DataFrame(
    cols_to_plot,
    index=month_name
)

# Plot
df_2020_open_close.plot(kind='bar', stacked=True, color=['pink', 'green', 'blue', 'red'], figsize=(25,10));
plt.title('Mean Open/Close/High/Low by Month ' + str(dom_2020_df['Year'].unique()[0]));

# %%
# Df's by year to plot mean values
dfs_to_plot = (dom_2015_df, dom_2016_df, dom_2017_df, dom_2018_df, dom_2019_df, dom_2020_df, dom_2021_df)

mean_close_values, pie_label, pie_explode = my_stock.get_mean_values_by_year(dfs_to_plot)

#np_zeros = np.zeros( len(dfs_to_plot))

# break parts
exploded = [float('0.' + str(int(pie_part / 4 ))) for pie_part in pie_explode]

plt.figure(figsize=(12,12))

plt.pie(
    mean_close_values, 
    labels = pie_label,
    explode=exploded,
    colors = ["#4CAF50", 'purple', '#000', 'red',  'pink', 'yellow', 'blue']
)

plt.legend(title = 'Domino\'s')

plt.show()

# %%
# TODO: method


#sns.set(style = 'whitegrid')
#sns.boxplot(x='Date', y='Close', data=pj_2015_df);

dict_day_max_price = {}

days = dom_2015_df['DayOfWeek'].unique()
#days= [1,2,3,4,5]
print(days)

list_maxprice = []
for day in days:
    #print(day)
    #dict_day_max_price[day] = pj_2015_df['Close'].loc[pj_2015_df['DayOfWeek'] == day  ].max()
    list_maxprice.append(dom_2015_df['Close'].loc[dom_2015_df['DayOfWeek'] == day].max())
    #print(dict_day_max_price[day])
    
print(list_maxprice)

dom_2015_byday = pd.DataFrame(
    data = {
            'Day' : days, 
            'Max_Price' : list_maxprice 
           }
)

dom_2015_byday

#sns.set_theme(style="whitegrid")

sns.set_style('darkgrid')
plt.figure(figsize=(20,12))
sns.set_palette('Set2')
sns.boxplot(data=dom_2015_df, x='DayOfWeek', y='Open')
sns.boxplot(data=dom_2016_df, x='DayOfWeek', y='Open')
sns.boxplot(data=dom_2017_df, x='DayOfWeek', y='Open')
sns.boxplot(data=dom_2018_df, x='DayOfWeek', y='Open')
sns.boxplot(data=dom_2019_df, x='DayOfWeek', y='Open')
#sns.boxplot(data=pj_2020_df, x='DayOfWeek', y='Open')
plt.show()

#ax = sns.boxplot(x='Day', y='Max_Price')
# Out:
# ['Friday' 'Monday' 'Tuesday' 'Wednesday' 'Thursday']
# [115.919998, 119.43, 118.790001, 118.540001, 115.57]

# %%
# Cuts - quartiles
dom_df.groupby(pd.cut(dom_df.Close, 4)).size()
# Out:
# Close
# (2.268, 143.205]     3028
# (143.205, 283.58]     791
# (283.58, 423.955]     447
# (423.955, 564.33]     226
# dtype: int64

# %% [markdown]
# ### Regplot (2019)

# %%
sns.regplot(x='Close', y='Open', data=dom_2019_df, scatter_kws={"color": "green"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Open'>

# %% [markdown]
# *References:*
# - [Wikipedia](https://en.wikipedia.org/wiki/Domino's_Pizza)
# - [Domino's Earnings](https://ir.dominos.com/financial-information/quarterly-earnings)
# - [Domino's Sugar Logo](https://freebiesupply.com/logos/domino-sugar-logo)
# - [DomiNick’s Pizza](https://www.scottspizzatours.com/blog/a-detroit-chain-pizza-pilgrimage)
# - [oohtoday.com](https://oohtoday.com/1st-original-recipe-oh-yes-we-did-2nd)
# - [Domino's Car](https://twitter.com/dominos/status/656954324329828352?ref_src=twsrc%5Etfw%7Ctwcamp%5Etweetembed%7Ctwterm%5E656954324329828352%7Ctwgr%5E%7Ctwcon%5Es1_&ref_url=https%3A%2F%2Fwww.insider.com%2Fdominos-pizza-created-a-delivery-car-with-a-built-in-oven-2015-10)
# - [marca.com](https://www.marca.com/coches-y-motos/coches/volkswagen/2020/05/04/5eb017e1ca47410a2e8b45c9.html)
